# %%
import numpy as np
import pandas as pd

# %%
df2 = pd.read_csv("preProcessed.csv")
df2
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      21914       1     151    67.0    120     80            2     2      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 62500  19699       1     172    70.0    130     90            1     1      0
# 62501  21074       1     165    80.0    150     80            1     1      0
# 62502  19240       2     168    76.0    120     80            1     1      1
# 62503  22431       1     163    72.0    135     80            1     2      0
# 62504  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio  age_years        bmi
# 0         0       1       0         50  21.967120
# 1         0       1       1         55  34.927679
# 2         0       0       1         51  23.507805
# 3         0       1       1         48  28.710479
# 4         0       0       0         60  29.384676
# ...     ...     ...     ...        ...        ...
# 62500     0       1       1         53  23.661439
# 62501     0       1       1         57  29.384757
# 62502     0       1       0         52  26.927438
# 62503     0       0       1         61  27.099251
# 62504     0       1       0         56  24.913495
#
# [62505 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
x = df2.drop(['cardio','age'], axis=1)
y = df2['cardio']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=43, stratify=y)
# stratify ->  Train: 55% zeros, 45% ones
              # Test : 55% zeros, 45% ones

print(X_train.shape)
print(X_test.shape)
# Out:
# (50004, 12)
# (12501, 12)

# %%
numeric_cols = X_train.select_dtypes(include='number').columns
numeric_cols
# Out:
# Index(['gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc',
#        'smoke', 'alco', 'active', 'age_years', 'bmi'],
#       dtype='object')

# %%
model = DecisionTreeClassifier(
    criterion="gini",
    max_depth=5,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", cm)
# Out:
# Accuracy: 0.7303415726741861
# Confusion Matrix:
#  [[5004 1323]
#  [2048 4126]]

# %%
train_acc = model.score(X_train, y_train)
test_acc = model.score(X_test, y_test)

print("Training Accuracy:", train_acc)
print("Testing Accuracy:", test_acc)
# Out:
# Training Accuracy: 0.7271218302535797
# Testing Accuracy: 0.7303415726741861
